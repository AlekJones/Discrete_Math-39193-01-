# %% [markdown]
# <a href="https://colab.research.google.com/github/AlekJones/Discrete_Math-39193-01-/blob/main/Online/ProjectPart4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # 4: CPSMA 3133 [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Counting
#
# ### Aleksander Jones

# %% [markdown]
# Today were looking at 10 events with 20 outcomes.
#
# For this project I'll be using football plays as the example. For play choices we have run, pass and kneel.
#
# ![football image.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# (A) First, if the outcomes were in order.

# %%
import math
plays = ["run", "pass", "kneel"]
outcome = 3**10
print("Total number of outcomes in order:", outcome)
# Out:
# Total number of outcomes in order: 59049

# %% [markdown]
# (B) For part b we will be examining if the outcomes of the plays didnt matter in any particular order.

# %%
import math
plays = ["run", "pass", "kneel"]
outcome = math.factorial(12)/(math.factorial(10)*math.factorial(2))
print("Total number of outcomes if order didnt matter:", outcome)
# Out:
# Total number of outcomes if order didnt matter: 66.0

# %% [markdown]
# (C) Without replacement if order mattered.

# %%
import math

print(math.factorial(3))
# Out:
# 6

# %% [markdown]
# (C) Without replacement if order didn't matter.

# %%
import math

math.factorial(3)/(math.factorial(0)*math.factorial(3))
# Out:
# 1.0

# %% [markdown]
# (D) What is the coefficent of the 5th order of (x − 3)9

# %% [markdown]
# I'm not sure how to code this one but I do know that (9!)/(4!*(5!)=  126

# %% [markdown]
# Other than the last part this task felt relatively simple?
# Nerves and being unsure of myself prevented me from accomplishing the goal at the end to code the math problem and I will have to work at it.
